# %%
import sys
sys.path.append('./../Training')

import tensorflow as tf
from BNN import BNN
from preprocess_data import *
import numpy as np
from utils import *
import matplotlib.pyplot as plt
import os

import subprocess

# %% [markdown]
# Load data

# %%
data_file = './../vmro3_refC1SD_70x36_13mdls_masked_extrap_and_interp.pkl'
X_train, y_train, X_test, y_test, X_interp, y_interp, X_extrap, y_extrap, X_at, y_at = read_data(data_file)
# Out:
# Number of obs: 439203
# Training on 83.1%
# Testing on 4.4%
# Validation (temporal extrapolation) on 6.8%
# Validation (interpolation) on 5.7%

# %% [markdown]
# Load BNNs

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth=True

# num_NNs needs changing
num_NNs = 48
checkpoint_dir = './../PreTrainedModels/model{}/'
log_dir = './logs/model{}/'
x_dim = X_train.shape[1]
y_dim = y_train.shape[1]
num_models = 13
n_data = X_train.shape[0]
hidden_size = 500
learning_rate = 0.0001

# Priors 
bias_mean = 0.00
bias_std = 0.02
noise_mean = 0.03
noise_std = 0.02
layer_scale = 1.1

alpha_dim = x_dim - num_models
init_std_1w =  np.sqrt(150.0/(alpha_dim))
init_std_1b = init_std_1w
init_std_2w =  (layer_scale)/np.sqrt(hidden_size)
init_std_2b = init_std_2w
init_std_biasw = (1.05 * layer_scale * bias_std)/np.sqrt(hidden_size)
init_std_noisew = (2.5)/np.sqrt(hidden_size)
lambda_anchor = 1.0/(np.array([init_std_1w,init_std_1b,init_std_2w,init_std_2b,init_std_biasw,init_std_noisew])**2)

# %%
# Load all the model details. These values below don't need to be changed even if the machine doesn't have 4 GPUs
# It is required so that the NNs are loaded onto the seperate Graphs that they were trained on.

num_gpus = 4
num_ens_members = 48
num_par_pro = 2
num_ens_per_pro = num_ens_members // (num_gpus * num_par_pro)

graphs = np.repeat([tf.Graph() for i in range(num_gpus * num_par_pro)], num_ens_per_pro)

ep_ = 100000

NNs = []
for i in range(num_NNs):
    with graphs[i].as_default():
        print('On graph {}:'.format(i))
        print('')
        sess = tf.Session(graph=graphs[i], config=config)
        NNs.append(BNN(sess, checkpoint_dir.format(i + 1),
                       log_dir.format(i + 1),
                       x_dim, y_dim, num_models, n_data,
                       hidden_size, learning_rate, lambda_anchor, 
                       init_std_1w, init_std_1b, init_std_2w,
                       init_std_2b, init_std_biasw, init_std_noisew,
                       load_from_epoch=ep_))
# Out:
# On graph 0:
#
# WARNING:tensorflow:From ./../Training/BNN.py:24: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From ./../Training/BNN.py:36: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From ./../Training/BNN.py:41: The name tf.layers.Dense is deprecated. Please use tf.compat.v1.layers.Dense instead.
#
# WARNING:tensorflow:From ./../Training/BNN.py:76: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From ./../Training/BNN.py:83: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From ./../Training/BNN.py:87: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From ./../Training/utils.py:6: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From ./../Training/utils.py:7: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From ./../Training/utils.py:10: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From ./../Training/BNN.py:92: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model1/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model1/BNN-100000
# Loading from pre-existing model
# On graph 1:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model2/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model2/BNN-100000
# Loading from pre-existing model
# On graph 2:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model3/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model3/BNN-100000
# Loading from pre-existing model
# On graph 3:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model4/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model4/BNN-100000
# Loading from pre-existing model
# On graph 4:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model5/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model5/BNN-100000
# Loading from pre-existing model
# On graph 5:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model6/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model6/BNN-100000
# Loading from pre-existing model
# On graph 6:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model7/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model7/BNN-100000
# Loading from pre-existing model
# On graph 7:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model8/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model8/BNN-100000
# Loading from pre-existing model
# On graph 8:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model9/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model9/BNN-100000
# Loading from pre-existing model
# On graph 9:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model10/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model10/BNN-100000
# Loading from pre-existing model
# On graph 10:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model11/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model11/BNN-100000
# Loading from pre-existing model
# On graph 11:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model12/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model12/BNN-100000
# Loading from pre-existing model
# On graph 12:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model13/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model13/BNN-100000
# Loading from pre-existing model
# On graph 13:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model14/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model14/BNN-100000
# Loading from pre-existing model
# On graph 14:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model15/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model15/BNN-100000
# Loading from pre-existing model
# On graph 15:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model16/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model16/BNN-100000
# Loading from pre-existing model
# On graph 16:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model17/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model17/BNN-100000
# Loading from pre-existing model
# On graph 17:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model18/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model18/BNN-100000
# Loading from pre-existing model
# On graph 18:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model19/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model19/BNN-100000
# Loading from pre-existing model
# On graph 19:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model20/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model20/BNN-100000
# Loading from pre-existing model
# On graph 20:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model21/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model21/BNN-100000
# Loading from pre-existing model
# On graph 21:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model22/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model22/BNN-100000
# Loading from pre-existing model
# On graph 22:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model23/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model23/BNN-100000
# Loading from pre-existing model
# On graph 23:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model24/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model24/BNN-100000
# Loading from pre-existing model
# On graph 24:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model25/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model25/BNN-100000
# Loading from pre-existing model
# On graph 25:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model26/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model26/BNN-100000
# Loading from pre-existing model
# On graph 26:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model27/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model27/BNN-100000
# Loading from pre-existing model
# On graph 27:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model28/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model28/BNN-100000
# Loading from pre-existing model
# On graph 28:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model29/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model29/BNN-100000
# Loading from pre-existing model
# On graph 29:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model30/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model30/BNN-100000
# Loading from pre-existing model
# On graph 30:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model31/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model31/BNN-100000
# Loading from pre-existing model
# On graph 31:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model32/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model32/BNN-100000
# Loading from pre-existing model
# On graph 32:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model33/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model33/BNN-100000
# Loading from pre-existing model
# On graph 33:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model34/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model34/BNN-100000
# Loading from pre-existing model
# On graph 34:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model35/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model35/BNN-100000
# Loading from pre-existing model
# On graph 35:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model36/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model36/BNN-100000
# Loading from pre-existing model
# On graph 36:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model37/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model37/BNN-100000
# Loading from pre-existing model
# On graph 37:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model38/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model38/BNN-100000
# Loading from pre-existing model
# On graph 38:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model39/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model39/BNN-100000
# Loading from pre-existing model
# On graph 39:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model40/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model40/BNN-100000
# Loading from pre-existing model
# On graph 40:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model41/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model41/BNN-100000
# Loading from pre-existing model
# On graph 41:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model42/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model42/BNN-100000
# Loading from pre-existing model
# On graph 42:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model43/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model43/BNN-100000
# Loading from pre-existing model
# On graph 43:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model44/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model44/BNN-100000
# Loading from pre-existing model
# On graph 44:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model45/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model45/BNN-100000
# Loading from pre-existing model
# On graph 45:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model46/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model46/BNN-100000
# Loading from pre-existing model
# On graph 46:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model47/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model47/BNN-100000
# Loading from pre-existing model
# On graph 47:
#
# Reading checkpoints...
# Loading from checkpoint: BNN-100000
# ./../PreTrainedModels/model48/BNN-100000
# INFO:tensorflow:Restoring parameters from ./../PreTrainedModels/model48/BNN-100000
# Loading from pre-existing model

# %%
def predict_ensemble(NNs, X):
    y_pred = []
    y_pred_noise_sq = []
    
    for i in range(num_NNs):
        with graphs[i].as_default():   
            y_pred.append(NNs[i].predict(X))
            y_pred_noise_sq.append(batch_retrieve(NNs[i], NNs[i].noise_sq, X))

    y_preds_train = np.array(y_pred)
    y_preds_noisesq_train = np.array(y_pred_noise_sq)
    y_preds_mu_train = np.mean(y_preds_train, axis=0)
    y_preds_std_train_epi = np.std(y_preds_train, axis=0)
    y_preds_std_train = np.sqrt(np.mean((y_preds_noisesq_train + np.square(y_preds_train)), axis = 0) - np.square(y_preds_mu_train))
    
    return y_preds_train, y_preds_mu_train, y_preds_std_train, y_preds_std_train_epi, y_preds_noisesq_train

# %%
# This line will take some time (minutes) to run on non GPU machines
y_preds_train, y_pred_train, y_std_train, y_epi_train, y_noise_train = predict_ensemble(NNs, X_train)
y_preds_test, y_pred_test, y_std_test, y_epi_test, y_noise_test = predict_ensemble(NNs, X_test)
y_preds_interp, y_pred_interp, y_std_interp, y_epi_interp, y_noise_interp = predict_ensemble(NNs, X_interp)
y_preds_extrap, y_pred_extrap, y_std_extrap, y_epi_extrap, y_noise_extrap = predict_ensemble(NNs, X_extrap)
y_preds_at, y_pred_at, y_std_at, y_epi_at, y_noise_at = predict_ensemble(NNs, X_at)

# %%
print('Training RMSE: {}'.format(calc_RMSE(y_pred_train, y_train)))
print('Testing RMSE: {}'.format(calc_RMSE(y_pred_test, y_test)))
print('Interp RMSE: {}'.format(calc_RMSE(y_pred_interp, y_interp)))
print('Extrap RMSE: {}'.format(calc_RMSE(y_pred_extrap, y_extrap)))
# Out:
# Training RMSE: 0.024788515642285347
# Testing RMSE: 0.026396289467811584
# Interp RMSE: 0.02757001481950283
# Extrap RMSE: 0.02613546885550022

# %%
print('Training NLL: {}'.format(calc_NLL(y_pred_train, y_train, y_std_train)))
print('Testing NLL: {}'.format(calc_NLL(y_pred_test, y_test, y_std_test)))
print('Interp NLL: {}'.format(calc_NLL(y_pred_interp, y_interp, y_std_interp)))
print('Extrap NLL: {}'.format(calc_NLL(y_pred_extrap, y_extrap, y_std_extrap)))
# Out:
# Training NLL: -3.465686559677124
# Testing NLL: -3.425260305404663
# Interp NLL: -3.1489429473876953
# Extrap NLL: -3.4940526485443115

# %%
print('For train')
report_on_percentiles(y_pred_train, y_train, y_std_train)
print('For test')
report_on_percentiles(y_pred_test, y_test, y_std_test)
print('For Extrap')
report_on_percentiles(y_pred_extrap, y_extrap, y_std_extrap)
print('For Interp')
report_on_percentiles(y_pred_interp, y_interp, y_std_interp)
# Out:
# For train
# Using 364995 data points
# 80.28055178838066 within 1 std
# 97.78188742311538 within 2 std
# 99.61232345648571 within 3 std
# For test
# Using 19286 data points
# 79.14549414082754 within 1 std
# 97.43337135746137 within 2 std
# 99.48148916312351 within 3 std
# For Extrap
# Using 29986 data points
# 77.62289068231841 within 1 std
# 97.42213032748616 within 2 std
# 99.52978056426332 within 3 std
# For Interp
# Using 24936 data points
# 70.98572345203722 within 1 std
# 94.71045877446262 within 2 std
# 99.05357715752326 within 3 std

# %% [markdown]
# ## Save raw BNN output - this data is still logged scaled - to preserve uncertainty

# %%
def recube(in_array):

    plev_len = 52
    lat_len = 36
    time_len = 31 * 12

    output = np.zeros([time_len, plev_len, lat_len])

    for t in range(time_len):
        output[t,:,:] = in_array[plev_len * lat_len * (t): plev_len * lat_len * (t+1)].reshape([plev_len, lat_len])
    
    return output

# %%
save_dir = './../BNNOutput'.format(ep_)
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
    
save_coords(data_file, save_dir)

# %%
weights = np.mean(get_weights(NNs, X_at), axis=2)
pkl.dump(weights, open(os.path.join(save_dir, 'weights.pkl'), 'wb'))

# %%
bias = np.mean(get_bias(NNs, X_at), axis=1)
pkl.dump(recube(bias), open(os.path.join(save_dir, 'bias.pkl'), 'wb'))

# %%
pkl.dump(y_pred_at, open(os.path.join(save_dir, 'pred.pkl'), 'wb'))

# %%
pkl.dump(y_std_at, open(os.path.join(save_dir, 'std.pkl'), 'wb'))

# %%
pkl.dump(recube(y_epi_at), open(os.path.join(save_dir, 'epi.pkl'), 'wb'))

# %%
pkl.dump(recube(np.mean(y_noise_at, axis=0)), open(os.path.join(save_dir, 'noise.pkl'), 'wb'))
